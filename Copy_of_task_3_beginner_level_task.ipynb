# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnaviravi506/LGMVIP-DataScience-Intern/blob/BEGINNER-LEVEL-TASK/Copy_of_task_3_beginner_level_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')

# %%
tracks = pd.read_csv('/content/tracks.csv')
tracks.head()
# Out:
#                          track                 trackid  \
# 0          Eyes of Abomination  0DL7M9oumLz11bI0oKiILH
# 1            You Can't Stop Me  4bIPDNw0hV5AdoJXi7zMXd
# 2              Fuck Everything  3oJKuFPVZTSeNc8G4UYV4L
# 3  Where Shadows Forever Reign  2vhEmSXSLMOcIlkvAF09zp
# 4                Toxic Boombox  3wqFctnDlFQzegLDCyW1LQ
#
#                 track_uri                   album_name  \
# 0  4PZPvAEhMw6zCsGQlqsYpw        Amaranthine Redolence
# 1  7FbrgGvv5ToVhdQpMsY3FU            You Can't Stop Me
# 2  005drRcJJFgFHgtxSJJO0v              The Black Crown
# 3  3K3aBG0PLVjlI7WdmYazak  Where Shadows Forever Reign
# 4  6OQizD2vNhBH3u1lMHsOjx     Rock the Fuck On Forever
#
#                  album_id           artist  duration  explicit  popularity  \
# 0  0DL7M9oumLz11bI0oKiILH       Malodorous    126000      True          22
# 1  4bIPDNw0hV5AdoJXi7zMXd  Suicide Silence    247840      True          44
# ...

# %%
tracks.shape
# Out:
# (2805, 26)

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2805 entries, 0 to 2804
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track             2805 non-null   object
#  1   trackid           2805 non-null   object
#  2   track_uri         2805 non-null   object
#  3   album_name        2805 non-null   object
#  4   album_id          2805 non-null   object
#  5   artist            2805 non-null   object
#  6   duration          2805 non-null   int64
#  7   explicit          2805 non-null   bool
#  8   popularity        2805 non-null   int64
#  9   danceability      2805 non-null   float64
#  10  energy            2805 non-null   float64
#  11  key               2805 non-null   int64
#  12  loudness          2805 non-null   float64
#  13  mode              2805 non-null   int64
#  14  speechiness       2805 non-null   float64
#  15  acousticness      2805 non-null   float64
# ...

# %%
tracks.isnull().sum()
# Out:
# track               0
# trackid             0
# track_uri           0
# album_name          0
# album_id            0
# artist              0
# duration            0
# explicit            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
tracks.dropna(inplace = True)
tracks.isnull().sum().plot.bar()
plt.show()

# %%
tracks = tracks.drop(['trackid', 'artist'], axis = 1)

# %%
tracks['album_name'].nunique(), tracks.shape
# Out:
# (1076, (2805, 24))

# %%
tracks = tracks.sort_values(by=['popularity'], ascending=False)
tracks.drop_duplicates(subset=['album_name'], keep='first', inplace=True)

# %%
plt.figure(figsize = (10, 5))
sb.countplot(tracks['duration'])
plt.axis('on')
plt.show()

# %%
floats = []
for col in tracks.columns:
  if tracks[col].dtype == 'float':
    floats.append(col)

len(floats)
# Out:
# 9

# %%
plt.subplots(figsize = (15, 5))
for i, col in enumerate(floats):
  plt.subplot(2, 5, i + 1)
  sb.distplot(tracks[col])
plt.tight_layout()
plt.show()

# %%
# %%capture
song_vectorizer = CountVectorizer()
song_vectorizer.fit(tracks['track'])

# %%
tracks = tracks.sort_values(by=['popularity'], ascending=False).head(10000)

# %%
def get_similarities(song_name, data):

  # Getting vector for the input song.
  text_array1 = song_vectorizer.transform(data[data['album_name']==song_name]['track']).toarray()
  num_array1 = data[data['album_name']==song_name].select_dtypes(include=np.number).to_numpy()

  # We will store similarity for each row of the dataset.
  sim = []
  for idx, row in data.iterrows():
    name = row['album_name']

    # Getting vector for current song.
    text_array2 = song_vectorizer.transform(data[data['album_name']==name]['track']).toarray()
    num_array2 = data[data['album_name']==name].select_dtypes(include=np.number).to_numpy()

    # Calculating similarities for text as well as numeric features
    text_sim = cosine_similarity(text_array1, text_array2)[0][0]
    num_sim = cosine_similarity(num_array1, num_array2)[0][0]
    sim.append(text_sim + num_sim)
  return sim

# %%
def recommend_songs(song_name, data=tracks):
  # Base case
  if tracks[tracks['album_name'] == song_name].shape[0] == 0:
    print('This song is either not so popular or you\
    have entered invalid_name.\n Some songs you may like:\n')

    for song in data.sample(n=5)['album_name'].values:
      print(song)
    return

  data['similarity_factor'] = get_similarities(song_name, data)

  data.sort_values(by=['similarity_factor', 'popularity'],
                   ascending = [False, False],
                   inplace=True)

  # First song will be the input song itself as the similarity will be highest.
  display(data[['album_name', 'artist']][2:7])

# %%
recommend_songs('Shape of You')
# Out:
# This song is either not so popular or you    have entered invalid_name.
#  Some songs you may like:
#
# Love On The Beat
# Serpentine Dominion
# Subjugate
# A Twisted Christmas
# Iron Maiden (1998 Remastered Edition)

# %%
recommend_songs('Love Someone')
# Out:
# This song is either not so popular or you    have entered invalid_name.
#  Some songs you may like:
#
# The Black Northern Ritual
# Spacer
# The Oracle (Deluxe Edition)
# We Were Never Meant To Be
# V . Halmstad

# %%
recommend_songs('Love me like you do')
# Out:
# This song is either not so popular or you    have entered invalid_name.
#  Some songs you may like:
#
# With Love
# No Control (2005 Remaster)
# You, Me, & The Violence
# The Who Hits 50 (Deluxe Edition)
# Let's Dance (1999 Remaster)
